# %% [markdown]
# <a href="https://colab.research.google.com/github/exalteded/DSPS_ejones/blob/master/KS_earthquakes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function, division
import pandas as pd
import pylab as pl
import scipy as sp
from scipy import stats
# %pylab inline
pl.style.use("https://raw.githubusercontent.com/fedhere/DSPS/master/fbb.mplstyle")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# 1 What is the test's Null Hypothsis that the K-S test tests?
#
# ## that two different empyrical data distrbution sets come from the same distribution in this case labeled k and l KS > dkl

# %% [markdown]
# 2 What is the "statistic" or "pivotal quantity" that the test uses?
#
# the pivotal quanitity is the distribution given by the probability density. Which serves to test the scaling function. (https://imgur.com/a/uJlQU7G), listed here formula (6) in corral 2018

# %% [markdown]
# 3 What does the probability distribution of this statistic depend on?
#
# It depends on the gamma function and each value of the distribution xn being independant of eachother.

# %%
pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS/master/HW3/earthquakes.csv", sep = " ",warn_bad_lines=True, skipinitialspace= True)
#there were some random variable spaces so skipinitial and sep were used and i added in the warn_bad_lines to warn me if there were any NaN in the 70k lines I can't see in the preview
# Out:
#        #YYY/MM/DD  HH:mm:SS.ss  ET GT   MAG  ... DEPTH  Q     EVID  NPH NGRM
# 0      1984/01/01  01:30:57.52  eq  l  2.02  ...   1.6  C    28255   13   17
# 1      1984/01/01  05:31:34.16  eq  l  2.12  ...   5.4  C    28259   18   42
# 2      1984/01/01  06:59:05.14  eq  l  2.43  ...   5.6  C    28260   13   30
# 3      1984/01/01  11:10:25.29  eq  l  2.07  ...  13.8  C    28270   19   40
# 4      1984/01/01  19:38:19.79  eq  l  2.13  ...   2.7  C    28553   40   49
# 5      1984/01/01  19:39:19.67  eq  l  2.13  ...  18.5  C    28282   32   41
# 6      1984/01/01  20:19:47.21  eq  l  2.02  ...  13.8  C    28284   31   59
# 7      1984/01/02  03:51:52.76  eq  l  2.97  ...   5.6  C    28297   14   19
# 8      1984/01/02  05:00:12.44  eq  l  3.24  ...   4.5  C    28575   40  130
# 9      1984/01/02  05:02:17.29  eq  l  2.17  ...   0.8  C    28299   17   19
# 10     1984/01/02  06:18:52.16  eq  l  2.48  ...   1.4  C    28304   28   93
# 11     1984/01/02  13:26:50.45  eq  l  2.65  ...  13.3  C    28319   15   77
# 12     1984/01/02  13:47:42.60  eq  l  3.17  ...   5.9  C    28320    5   30
# 13     1984/01/02  14:01:05.85  eq  l  2.44  ...  12.8  C    28321   18   49
# 14     1984/01/02  15:21:08.12  eq  l  3.02  ...   3.8  C    28330   11   76
# 15     1984/01/02  18:43:18.09  eq  l  2.10  ...   1.5  C    28337   19   31
# 16     1984/01/03  06:37:11.36  eq  l  2.41  ...   5.1  C    28354   23   85
# 17     1984/01/03  10:52:01.17  eq  l  2.29  ...   6.5  C    28362   37   47
# 18     1984/01/03  13:26:56.21  eq  l  2.09  ...   8.8  C    28373   14   45
# 19     1984/01/03  19:44:09.71  eq  l  3.17  ...   5.6  C    28389   24   67
# 20     1984/01/04  03:39:11.87  eq  l  2.03  ...  11.0  C    28408   32   61
# 21     1984/01/04  06:05:10.56  eq  l  2.80  ...   5.6  C    28410   18   34
# 22     1984/01/04  06:17:22.59  eq  l  2.75  ...   5.6  C    28411   16   36
# 23     1984/01/04  09:30:11.96  eq  l  2.92  ...   5.5  C    28415    5   12
# 24     1984/01/04  11:43:05.02  eq  l  2.32  ...   6.3  C    28417   21   71
