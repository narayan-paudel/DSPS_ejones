# %% [markdown]
# <a href="https://colab.research.google.com/github/exalteded/DSPS_ejones/blob/master/HW4/circle_Lab_Elliott.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline

def square(side):
    ax = plt.figure(figsize =(5,5)).add_subplot(1,1,1)
    plt.scatter(-side,-side)
    plt.scatter(-side,side)
    plt.scatter(side,-side)
    plt.scatter(side,side)
    plt.plot([0-side,0-side],[-side,side])
    plt.plot([-side,side],[side,side])
    plt.plot([side,side],[side,-side])
    plt.plot([side,-side],[-side,-side])
    
    return ax
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !pip install astropy

# %%
from astropy import units as u

def circle(radius,ax):
  angle = np.arange(0,360,0.1)
  angle *= u.degree
  x = radius * np.cos(angle.to(u.rad))
  y = radius * np.sin(angle.to(u.rad))
 #print('x: ', x)
 #print('y: ', y)
  ax.plot(x,y)
  
ax = plt.figure().add_subplot(1,1,1)

# %%
axis = square(1)
circle(1,axis)
np.random.seed(300)
num_x = 2 * np.random.rand(900) - 1
num_y = 2 * np.random.rand(900) - 1

axis.scatter(num_x,num_y)

r = np.sqrt((num_x**2)+ (num_y**2))
#print(r)
r_in = r[ r < 1]

print(len(r_in))
print((4*len(r_in)/900))
# Out:
# 702
# 3.12

# %%
axis1 = square(1)
circle(1,axis1)
np.random.seed(300)
num_x1 = 2 * np.random.rand(90) - 1
num_y1 = 2 * np.random.rand(90) - 1

axis1.scatter(num_x1,num_y1)

r1 = np.sqrt((num_x1**2)+ (num_y1**2))
#print(r1)
r1_in = r1[ r1 < 1]

print(len(r1_in))
print((4*len(r1_in)/90))
# Out:
# 74
# 3.2888888888888888

# %%
axis2 = square(1)
circle(1,axis2)
np.random.seed(300)
num_x2 = 2 * np.random.rand(100000) - 1
num_y2 = 2 * np.random.rand(100000) - 1

axis2.scatter(num_x2,num_y2)

r2 = np.sqrt((num_x2**2)+ (num_y2**2))
#print(r2)
r2_in = r2[ r2 < 1]

print(len(r2_in))
print((4*len(r2_in)/100000))
# Out:
# 78433
# 3.13732

# %% [markdown]
# All of these approximate Pi and as we add more and more points the approximation gets better and better.
